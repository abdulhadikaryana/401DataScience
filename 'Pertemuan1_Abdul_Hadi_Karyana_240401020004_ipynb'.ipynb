# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhadikaryana/401DataScience/blob/main/'Pertemuan1_Abdul_Hadi_Karyana_240401020004_ipynb'.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan Pertama. Notebook Pertama Data Science

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# Variabel dan tipe data dasar

# %%
nama = "Mahasiswa Informatika" # String
angkatan = 2024 # Integer
ipk = 3.75 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %% [markdown]
# list dan perualangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Abdul Hadi Karyana", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Abdul Hadi Karyana dari Informatika, angkatan 2024.
